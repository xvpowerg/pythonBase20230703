# %% [markdown]
# # 作業
# ![image.png](attachment:image.png)

# %%
height = input("請輸入身高 單位公分:")
weight = input("請輸入體重 單位公斤:")
bmi = int(weight)/(int(height)/100)**2
print(bmi)
if bmi < 18.5:
    print("太輕")
elif  bmi < 25:
    print("正常")
elif bmi < 30:
    print("過重")
else:
    print("胖胖")

# %%
str1 = "你好'ken'"
str2 = '你好"vivin"'
print(str1)
print(str2)
# Out:
# 你好'ken'
# 你好"vivin"

# %% [markdown]
# str3 = """中電電信光世代先前宣布推出「雙向對稱頻寬」，
# 也就是網路上傳速度與下載速度祥同，針對300M／150M、500M／
# 250M升級為300M／300M和500M／"500M"，老用戶則可以「免費升級」，
# 想知道自己是否已經升級了嗎？原文網址: 中華電信光世代網速升級了嗎？
# 2方法查家中網路速率"""
# print(str3)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
mystring2 ="ABCDEFGH"
print(mystring2[0])
print(mystring2[3])
print(mystring2[-1])
print(mystring2[-2])

print(mystring2[2:])
print(mystring2[2:5])
print(mystring2[5:])
print(mystring2[-3:0])
# Out:
# A
# D
# H
# G
# CDEFGH
# CDE
# FGH
# FG

# %%
str3 = "Java Python Golan C#"
str4 = str3.replace("P","p") #回傳一組修改好的新字串
print(str3)
print(str4)
str5 = str3.replace("a","-")
print(str5)
# Out:
# Java Python Golan C#
# Java python Golan C#
# J-v- Python Gol-n C#

# %%
str3 = "Java Python Golan C#"
print(str3.find("Python"))
print(str3.find("a"))#找到就停不會繼續往下找
# Out:
# 5
# 1

# %%
str4 = "_"
str5 = ["a","b","c"]
print(str4.join(str5))
# Out:
# a_b_c

# %%
str4 = "python,java,c#,golan"
str5 =  str4.split(",")
print(str5)
print(str5[0])
print(str5[2])
# Out:
# ['python', 'java', 'c#', 'golan']
# python
# c#

# %% [markdown]
# ## List

# %%
myList = ["A","B","C"]
print(myList[1])
myList[1] = "Banana"
print(myList[1])
# Out:
# B
# Banana

# %%
myTuple = ("A",'B',"C")#只能讀取
print(myTuple[1])
myTuple[1] = "Ben"# 因為tuple無法更新數值所以會出錯
print(myTuple[1])
# Out:
# B
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 myTuple = ("A",'B',"C")
#       2 print(myTuple[1])
# ----> 3 myTuple[1] = "Ben"
#       4 print(myTuple[1])
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myList = ["A","B","C","D","E"]
print(myList[1:4])
print(myList[-3:-1])
print(myList[1:])
# Out:
# ['B', 'C', 'D']
# ['C', 'D']
# ['B', 'C', 'D', 'E']

# %%
myList = ["A","B","C"]
print(len(myList))
myList.append("D")#往尾部加入
print(len(myList))
print(myList)
myList += "E" #不建議
print(myList)
# Out:
# 3
# 4
# ['A', 'B', 'C', 'D']
# ['A', 'B', 'C', 'D', 'E']

# %%
myList1 = ["Python","Java"]
myList2 = ["C++","Unity","Golan"]
myList1.append(myList2)
print(len(myList1))
print(myList1)
# Out:
# 3
# ['Python', 'Java', ['C++', 'Unity', 'Golan']]

# %%
myList1 = ["Python","Java"]
myList2 = ["C++","Unity","Golan"]
myList1.extend(myList2)
print(len(myList1))
print(myList1)
# Out:
# 5
# ['Python', 'Java', 'C++', 'Unity', 'Golan']

# %%
myList1 = ["A","B","C"]
print(myLis1)
myList1.insert(1,"Z")
print(myList1)
myList1.insert(3,"S")
print(myList1)
# Out:
# ['A', 'B', 'C']
# ['A', 'Z', 'B', 'C']
# ['A', 'Z', 'B', 'S', 'C']
